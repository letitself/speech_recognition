# %%
import os, shutil
rootdir = 'recordings' #корневая

#move all needed files from archive to one directory
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        print('/Users/tarasandrushko/Desktop/coursework/' + os.path.join(subdir, file)) 
        shutil.copy('/Users/tarasandrushko/Desktop/coursework/' + os.path.join(subdir, file), '/Users/tarasandrushko/Desktop/coursework/corp/') #куда двигать
# Out:
# /Users/tarasandrushko/Desktop/coursework/recordings/9/.DS_Store
# /Users/tarasandrushko/Desktop/coursework/recordings/9/61/4bd457b6d814.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/61/4bd457b6d814.opus
# /Users/tarasandrushko/Desktop/coursework/recordings/9/0d/d5f2e73f89b5.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/0d/1a0003f3675e.opus
# /Users/tarasandrushko/Desktop/coursework/recordings/9/0d/1a0003f3675e.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/0d/d5f2e73f89b5.opus
# /Users/tarasandrushko/Desktop/coursework/recordings/9/95/e31106092373.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/95/e30a62f7457a.opus
# /Users/tarasandrushko/Desktop/coursework/recordings/9/95/e31106092373.opus
# /Users/tarasandrushko/Desktop/coursework/recordings/9/95/e30a62f7457a.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/59/08da5912ea9d.txt
# /Users/tarasandrushko/Desktop/coursework/recordings/9/59/7907a6f5acca.txt
# ...

# %%
import os
main_path = 'coursework'

# %%
os.getcwd()
# Out:
# '/Users/tarasandrushko/Desktop/coursework'

# %%
#this scripts move files with the same format to new directory
import glob, os, shutil

source_dir = 'audio' #Path where your files are at the moment
dst = '/Users/tarasandrushko/Desktop/coursework/trash/' #Path you want to move your files to
files = glob.iglob(os.path.join(source_dir, "*.opus"))
for file in files:
    if os.path.isfile(file):
        shutil.move(file, dst)

# %%
os.getcwd()
# Out:
# '/Users/tarasandrushko/Desktop/coursework'

# %%
for i in *.opus; do ffmpeg -i "$i" "${i%.*}.wav"; done #print it in the terminal(do not forget about in which directory you are working in)
# Out:
#   File "/var/folders/jb/cmr5rp_d6152fynb4pj11ph80000gn/T/ipykernel_73288/2036898113.py", line 1
#     for i in *.opus:
#               ^
# SyntaxError: invalid syntax
